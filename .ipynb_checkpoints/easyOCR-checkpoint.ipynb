# %%
import easyocr

# %%
#download the model
reader = easyocr.Reader(['fr'], gpu = False)
# Out:
# Using CPU. Note: This module is much faster with a GPU.

# %%
# afficher une image
import PIL
from PIL import ImageDraw
import tkinter as tk
from tkinter import filedialog
import matplotlib.pyplot as plt
root = tk.Tk()
root.withdraw()
    # Ask the user to select an image file using a file dialog box
file_path = filedialog.askopenfilename(filetypes=[("Image files", "*.jpg;*.jpeg;*.png")])
im = PIL.Image.open(file_path)
plt.imshow(im)
plt.show()

# %%
# faire un OCR. Obtenez des boîtes englobantes.
bounds = reader.readtext(file_path)
bounds
# Out:
# [[[[43, 30], [692, 30], [692, 283], [43, 283]], 'esprit', 0.6338760582657823],
#  [[[883, 101], [1865, 101], [1865, 215], [883, 215]],
#   'CARTE ETUDIANT',
#   0.5911948048666424],
#  [[[358, 224], [746, 224], [746, 277], [358, 277]],
#   'Se former autrement',
#   0.891084375378744],
#  [[[1076, 232], [1845, 232], [1845, 293], [1076, 293]],
#   'Annee universitaire 2022/2023',
#   0.7921608819991046],
#  [[[63, 297], [259, 297], [259, 333], [63, 333]],
#   '-٥w٥Rs',
#   0.16725308342717898],
#  [[[271, 298], [739, 298], [739, 339], [271, 339]],
#   'UNITED UNIVERSITIES',
#   0.7461008541571901],
#  [[[1300, 330], [1674, 330], [1674, 405], [1300, 405]],
#   '2022/ 2023',
#   0.615955679018415],
#  [[[55, 415], [251, 415], [251, 477], [55, 477]], 'NOM :', 0.9669590274413203],
#  [[[515, 443], [871, 443], [871, 507], [515, 507]],
#   'ALI LAHBIB',
#   0.7395402651845436],
#  [[[46, 588], [384, 588], [384, 662], [46, 662]],
#   'PRENOM :',
#   0.9998097329231999],
#  [[[507, 623], [957, 623], [957, 686], [507, 686]],
#   'Mohamed Zied',
#   0.9519431547383028],
#  [[[42, 776], [358, 776], [358, 848], [42, 848]],
#   'CLASSE :',
#   0.6726114985409822],
#  [[[480, 791], [1072, 791], [1072, 866], [480, 866]],
#   'Seme annee (5SE4)',
#   0.5125374825037206],
#  [[[37, 937], [499, 937], [499, 1005], [37, 1005]],
#   'IDENTIFIANT :',
#   0.6146166158648334],
#  [[[597, 959], [985, 959], [985, 1023], [597, 1023]],
#   '203JMT0209',
#   0.7339257884790427]]

# %%
# Dessiner des cadres 
def draw_boxes(image, bounds, color='red', width=2):
    draw = ImageDraw.Draw(image)
    for bound in bounds:
        p0, p1, p2, p3 = bound[0]
        draw.line([*p0, *p1, *p2, *p3, *p0], fill=color, width=width)
    return image

draw_boxes(im, bounds)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1968x1120>

# %%
len(bounds)
# Out:
# 15

# %%
for i in bounds:
    print(i[1])
# Out:
# esprit
# CARTE ETUDIANT
# Se former autrement
# Annee universitaire 2022/2023
# -٥w٥Rs
# UNITED UNIVERSITIES
# 2022/ 2023
# NOM :
# ALI LAHBIB
# PRENOM :
# Mohamed Zied
# CLASSE :
# Seme annee (5SE4)
# IDENTIFIANT :
# 203JMT0209
